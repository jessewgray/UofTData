# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
#import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities
# Out:
# ['tasiilaq',
#  'new norfolk',
#  'illoqqortoormiut',
#  'lorengau',
#  'ancud',
#  'clarksburg',
#  'pangnirtung',
#  'santa rosa',
#  'east london',
#  'punta arenas',
#  'taolanaro',
#  'tapaua',
#  'pochutla',
#  'barrow',
#  'belushya guba',
#  'suksun',
#  'acapulco',
#  'kodiak',
#  'saint-philippe',
#  'znamenka',
#  'praia da vitoria',
#  'plettenberg bay',
#  'khorixas',
#  'tiksi',
#  'college',
#  'thompson',
#  'bandarbeyla',
#  'vaini',
#  'betanzos',
#  'hobart',
#  'springfield',
#  'vao',
#  'shulan',
#  'parrita',
#  'rikitea',
#  'katesh',
#  'meulaboh',
#  'ribeira grande',
#  'kapaa',
#  'avarua',
#  'grants pass',
#  'mataura',
#  'bredasdorp',
#  'saldanha',
#  'ushuaia',
#  'atar',
#  'faya',
#  'bloomfield',
#  'beringovskiy',
#  'xapuri',
#  'dingle',
#  'noumea',
#  'arboletes',
#  'alofi',
#  'ushtobe',
#  'laiyang',
#  'rosetta',
#  'balkhash',
#  'harper',
#  'itaituba',
#  'arraial do cabo',
#  'maningrida',
#  'carnarvon',
#  'nechanice',
#  'narsaq',
# ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
totalCitiesSeries = []

for city in cities:
    try:
#city = input('pick a city ')
        baseUrl = "http://api.openweathermap.org/data/2.5/weather?q=" + city.replace(" ", "") + "&units=imperial&APPID="

        #baseUrl = "http://api.openweathermap.org/data/2.5/weather?lat=43.65&lon=-79.39&APPID="
        apiKey = "41ed0fa71109712597d1d5e12e282f0d"
        units = "units=metric"
        combinedUrl = baseUrl + apiKey 

        data = requests.get(combinedUrl).json()

        cityName = data['name']
        lon = data['coord']['lon']
        lat = data['coord']['lat']
        tempF = data['main']['temp']
        tempC = (data['main']['temp'] - 32) * .5556
        tempC = round(tempC, 2)
        humidityPercent = data['main']['humidity']
        cloudinessPercent = data['clouds']['all']
        windSpeedMph = data['wind']['speed']

        cityDataDict = {"Name": cityName, 
                "Longitude": lon, 
                "Latitude": lat, 
                "Temp(F)": tempF, 
                "Temp(C)": tempC, 
                "Humidity(%)": humidityPercent,
                "Cloudiness(%)": cloudinessPercent, 
                "Wind Speed(mph)": windSpeedMph}

        totalCitiesSeries.append(cityDataDict)
    except KeyError:
         continue
    
totalCitiesSeries
totalCitiesDF = pd.DataFrame(totalCitiesSeries)
print(totalCitiesDF)
# Out:
#      Cloudiness(%)  Humidity(%)  Latitude  Longitude            Name  Temp(C)  \
# 0               92           93     65.61     -37.64        Tasiilaq     2.00
# 1               76          100     -2.02     147.27        Lorengau    26.78
# 2               92           96    -41.87     -73.83           Ancud    12.86
# 3               90           54     39.28     -80.34      Clarksburg    13.51
# 4               75           36     66.15     -65.72     Pangnirtung    -9.00
# 5                1           55     34.68     -80.78       Santarosa    18.35
# 6               20           58     15.74     -96.47        Pochutla    31.00
# 7                8           31    -38.31     -60.23          Barrow    28.30
# 8               92           96     57.15      57.40          Suksun    -2.20
# 9                5           70     16.86     -99.88        Acapulco    30.00
# 10              75           64     39.95     -94.76          Kodiak     5.00
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
totalCitiesDF.to_csv("totalCitiesDF.csv", encoding='utf-8', index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
cityLatX = totalCitiesDF['Latitude']
cityTempFY = totalCitiesDF['Temp(F)']
cityTempCY = totalCitiesDF['Temp(C)']

latVStempF = plt.scatter(cityLatX, cityTempFY, color="yellow", label="Fahrenheit", alpha=".7", edgecolors= "black", s=100)
latVStempC = plt.scatter(cityLatX, cityTempCY, color="lightblue", label="Celcius", alpha=".7", edgecolors= "black", s=100)

plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Latitude vs. Temperature Plot')
legend = plt.legend(title="Temperature", loc='upper right')
legend.legendHandles[0]._sizes = [100]
legend.legendHandles[1]._sizes = [100]
plt.grid(True)
plt.savefig("latitudevstemperatureplot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
cityLatX = totalCitiesDF['Latitude']
cityHumidityY = totalCitiesDF['Humidity(%)']


latVShumidity = plt.scatter(cityLatX, cityHumidityY, color="purple", label="Humidity", alpha=".7", edgecolors= "black", s=100)

plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Latitude vs. Humidity Plot')
plt.grid(True)
plt.savefig("latitudevshumidityplot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cityLatX = totalCitiesDF['Latitude']
cityCloudinessY = totalCitiesDF['Cloudiness(%)']


latVScloudiness = plt.scatter(cityLatX, cityCloudinessY, color="grey", label="Cloudiness", alpha=".7", edgecolors= "black", s=100)

plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('Latitude vs. Cloudiness Plot')
plt.grid(True)
plt.savefig("latitudevscloudinessplot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
cityLatX = totalCitiesDF['Latitude']
cityWindSpeedY = totalCitiesDF['Wind Speed(mph)']


latVSwind = plt.scatter(cityLatX, cityWindSpeedY, color="green", label="Wind Speed (mph)", alpha=".7", edgecolors= "black", s=100)

plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.title('Latitude vs. Wind Speed Plot')
plt.grid(True)
plt.savefig("latitudevswindspeedplot.png")
plt.show()
