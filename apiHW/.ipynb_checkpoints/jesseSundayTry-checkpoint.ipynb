# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities
# Out:
# ['kaminoyama',
#  'lebu',
#  'arraial do cabo',
#  'te anau',
#  'cape town',
#  'hobart',
#  'mataura',
#  'rikitea',
#  'ostrovnoy',
#  'castro',
#  'komsomolskiy',
#  'coari',
#  'jinxiang',
#  'miranorte',
#  'qaanaaq',
#  'nelson',
#  'ushuaia',
#  'tasiilaq',
#  'jamestown',
#  'laurel',
#  'mahebourg',
#  'demidov',
#  'kourou',
#  'sahuaripa',
#  'mys shmidta',
#  'hermanus',
#  'katangli',
#  'torbay',
#  'vaini',
#  'nizhneyansk',
#  'caloundra',
#  'cabo san lucas',
#  'narsaq',
#  'new norfolk',
#  'noumea',
#  'kruisfontein',
#  'atuona',
#  'acapulco',
#  'touros',
#  'port elizabeth',
#  'hamilton',
#  'snizhne',
#  'georgetown',
#  'berlevag',
#  'ilulissat',
#  'kodiak',
#  'nikolskoye',
#  'lac-megantic',
#  'vitimskiy',
#  'bluff',
#  'dunedin',
#  'cidreira',
#  'larsnes',
#  'emerald',
#  'sechura',
#  'coos bay',
#  'taolanaro',
#  'punta arenas',
#  'labutta',
#  'mandan',
#  'roald',
#  'ust-maya',
#  'conceicao do mato dentro',
#  'sentyabrskiy',
#  'reconquista',
#  'maniitsoq',
#  'rorvik',
#  'hihifo',
#  'albany',
#  'merauke',
#  'bathsheba',
#  'svetlaya',
#  'namibe',
#  'ust-nera',
#  'katima mulilo',
#  'lake city',
#  'pevek',
#  'tuktoyaktuk',
#  'busselton',
#  'amderma',
#  'tabuk',
#  'balkhash',
#  'puerto ayora',
#  'kapaa',
#  'karaton',
#  'raga',
#  'airai',
#  'kez',
#  'belushya guba',
#  'prince rupert',
#  'dikson',
#  'weyburn',
#  'saint-georges',
#  'harper',
#  'high rock',
#  'cherskiy',
#  'dali',
#  'naryan-mar',
#  'souillac',
#  'bud',
#  'kavaratti',
#  'marawi',
#  'qarqin',
#  'maghama',
#  'hilo',
#  'andselv',
#  'thompson',
#  'chuy',
#  'espinosa',
#  'hithadhoo',
#  'brae',
#  'waipawa',
#  'samusu',
#  'barentsburg',
#  'leningradskiy',
#  'mbaiki',
#  'tateyama',
#  'wilkie',
#  'kulhudhuffushi',
#  'grindavik',
#  'cam pha',
#  'bredasdorp',
#  'ponta delgada',
#  'jieshi',
#  'nadym',
#  'birin',
#  'upernavik',
#  'nusaybin',
#  'butaritari',
#  'sao joao da barra',
#  'barrow',
#  'cayenne',
#  'mount darwin',
#  'upata',
#  'esperance',
#  'hanmer springs',
#  'creel',
#  'talnakh',
#  'sangar',
#  'srednekolymsk',
#  'bullhead city',
#  'los llanos de aridane',
#  'kahului',
#  'salalah',
#  'kaitangata',
#  'port alfred',
#  'lata',
#  'mackay',
#  'garliava',
#  'naze',
#  'wellsford',
#  'saint-louis',
#  'ardakan',
#  'henties bay',
#  'mount gambier',
#  'severo-kurilsk',
#  'port macquarie',
#  'tapes',
#  'tadine',
#  'jiwani',
#  'port-cartier',
#  'atasu',
#  'saint george',
#  'tostedt',
#  'illoqqortoormiut',
#  'bocaiuva',
#  'faanui',
#  'huilong',
#  'avarua',
#  'barra de sao francisco',
#  'husavik',
#  'nome',
#  'kuryk',
#  'mitchell',
#  'ribeira grande',
#  'fillmore',
#  'umm kaddadah',
#  'bethel',
#  'saint-joseph',
#  'saint-philippe',
#  'palu',
#  'attawapiskat',
#  'sambava',
#  'tura',
#  'padang',
#  'manzhouli',
#  'champerico',
#  'trincomalee',
#  'grand-lahou',
#  'poshekhonye',
#  'tasbuget',
#  'nanortalik',
#  'cururupu',
#  'grand forks',
#  'antonio escobedo',
#  'flinders',
#  'dwarka',
#  'grand gaube',
#  'bengkulu',
#  'waddan',
#  'mizdah',
#  'yellowknife',
#  'alamogordo',
#  'taburi',
#  'ericeira',
#  'konevo',
#  'norman wells',
#  'sahrak',
#  'poum',
#  'ahuimanu',
#  'auki',
#  'kupino',
#  'kuldur',
#  'arlit',
#  'sola',
#  'amara',
#  'jalu',
#  'aklavik',
#  'pochutla',
#  'barra do bugres',
#  'melito di porto salvo',
#  'quelimane',
#  'lengshuitan',
#  'lorengau',
#  'saleaula',
#  'uporovo',
#  'chokurdakh',
#  'pendleton',
#  'matagami',
#  'mantua',
#  'paita',
#  'saint anthony',
#  'tsihombe',
#  'naukot',
#  'pithoragarh',
#  'jiexiu',
#  'khonuu',
#  'san cristobal',
#  'bonfim',
#  'bulgan',
#  'san vicente',
#  'jasper',
#  'penalva',
#  'maragogi',
#  'magdalena',
#  'suratgarh',
#  'micomeseng',
#  'lisala',
#  'alofi',
#  'clyde river',
#  'krasnoselkup',
#  'lure',
#  'ardistan',
#  'rawson',
#  'carnarvon',
#  'french harbor',
#  'portland',
#  'la ronge',
#  'fortuna',
#  'manokwari',
#  'manyana',
#  'north augusta',
#  'rio branco',
#  'falavarjan',
#  'vardo',
#  'clovis',
#  'hatillo',
#  'yei',
#  'hambantota',
#  'mar del plata',
#  'marcona',
#  'ust-kamchatsk',
#  'mana',
#  'ancud',
#  'ushtobe',
#  'tumannyy',
#  'bilma',
#  'ballina',
#  'khatanga',
#  'turukhansk',
#  'san quintin',
#  'lavrentiya',
#  'kodino',
#  'vila franca do campo',
#  'santa maria',
#  'graaff-reinet',
#  'parana',
#  'victoria',
#  'san patricio',
#  'east london',
#  'dzhusaly',
#  'valera',
#  'deputatskiy',
#  'hasaki',
#  'gijon',
#  'louisbourg',
#  'tornio',
#  'fairbanks',
#  'caravelas',
#  'mount isa',
#  'tiksi',
#  'nemuro',
#  'bollnas',
#  'katsuura',
#  'laguna',
#  'provideniya',
#  'galgani',
#  'santa rosa',
#  'shache',
#  'alice springs',
#  'hami',
#  'lompoc',
#  'hameenlinna',
#  'weligama',
#  'oranjemund',
#  'cap malheureux',
#  'aquiraz',
#  'bereznehuvate',
#  'toda bhim',
#  'ponta do sol',
#  'comodoro rivadavia',
#  'lasa',
#  'tuatapere',
#  'safakulevo',
#  'praia',
#  'hobyo',
#  'bose',
#  'cockburn town',
#  'umzimvubu',
#  'dubbo',
#  'skibbereen',
#  'ambon',
#  'qurayyat',
#  'hualmay',
#  'ketchikan',
#  'bisira',
#  'stephenville',
#  'filadelfia',
#  'ketou',
#  'yulara',
#  'shubarshi',
#  'pamanukan',
#  'itapeva',
#  'pisco',
#  'kaberamaido',
#  'palmer',
#  'xinmin',
#  'zhukovo',
#  'tilichiki',
#  'sao felix do xingu',
#  'maarianhamina',
#  'lima',
#  'luwingu',
#  'puri',
#  'kavieng',
#  'leshukonskoye',
#  'yanan',
#  'hendijan',
#  'akdepe',
#  'pruszkow',
#  'mao',
#  'saskylakh',
#  'kailaras',
#  'carauari',
#  'lagoa',
#  'ternate',
#  'luderitz',
#  'kutum',
#  'dakar',
#  'panzhihua',
#  'halden',
#  'mineral wells',
#  'boyuibe',
#  'sumter',
#  'solnechnyy',
#  'beringovskiy',
#  'akyab',
#  'amga',
#  'berbera',
#  'najran',
#  'novopavlovka',
#  'burica',
#  'dharchula',
#  'echirolles',
#  'marsabit',
#  'samalaeulu',
#  'sobolevo',
#  'antalaha',
#  'ayagoz',
#  'jinchang',
#  'emet',
#  'keningau',
#  'port-gentil',
#  'hovd',
#  'buala',
#  'shimoda',
#  'amritsar',
#  'aswan',
#  'coahuayana',
#  'mandalgovi',
#  'progreso',
#  'yaan',
#  'kultuk',
#  'lingyuan',
#  'martyush',
#  'kon tum',
#  'san ramon de la nueva oran',
#  'pierre',
#  'dubrovnik',
#  'dehloran',
#  'kolpashevo',
#  'pangnirtung',
#  'klaksvik',
#  'buin',
#  'xambioa',
#  'bur gabo',
#  'ferrol',
#  'chiusi',
#  'road town',
#  'christchurch',
#  'abu zabad',
#  'geraldton',
#  'chapleau',
#  'masallatah',
#  'batouri',
#  'palabuhanratu',
#  'yekimovichi',
#  'bangkalan',
#  'samarai',
#  'rocha',
#  'zhigansk',
#  'kiunga',
#  'dien bien',
#  'birao',
#  'la palma',
#  'bubaque',
#  'nauta',
#  'bambous virieux',
#  'krasnogorskoye',
#  'kudahuvadhoo',
#  'kaeo',
#  'tommot',
#  'sitka',
#  'buzmeyin',
#  'cabo rojo',
#  'maun',
#  'southbridge',
#  'muravlenko',
#  'guerrero negro',
#  'bryant',
#  'port lincoln',
#  'benguela',
#  'sao filipe',
#  'saldanha',
#  'sarkhej',
#  'waingapu',
#  'goroka',
#  'mezen',
#  'gigmoto',
#  'vangaindrano',
#  'yumen',
#  'melenki',
#  'cuajinicuilapa',
#  'palana',
#  'sisimiut',
#  'ahipara',
#  'grand river south east',
#  'apatity',
#  'paamiut',
#  'lormi',
#  'ituiutaba',
#  'safita',
#  'methoni',
#  'eureka',
#  'mezhova',
#  'panaba',
#  'chagda',
#  'teahupoo',
#  'atar',
#  'calama',
#  'port blair',
#  'meulaboh',
#  'neijiang',
#  'tiznit',
#  'muros',
#  'gurskoye',
#  'manama',
#  'fare',
#  'fethiye',
#  'ilheus',
#  'nouakchott',
#  'coquimbo',
#  'kholm',
#  'zalantun',
#  'spokane',
#  'arona',
#  'huaihua',
#  'asau',
#  'leh',
#  'koungou',
#  'moussoro',
#  'bajo baudo',
#  'saint-leu',
#  'bolshaya dzhalga',
#  'aroeiras',
#  'okato',
#  'issoire',
#  'half moon bay',
#  'lucea',
#  'humberto de campos',
#  'necochea',
#  'kurilsk',
#  'nantucket',
#  'quatre cocos',
#  'kalmunai',
#  'kendari',
#  'marrakesh',
#  'satuk',
#  'san carlos de bariloche',
#  'isiro',
#  'iqaluit',
#  'tomatlan',
#  'saravan',
#  'sekoma',
#  'bilibino',
#  'tsabong',
#  'hsinhua',
#  'skagastrond',
#  'maumere',
#  'dulce nombre de culmi',
#  'goderich',
#  'kurchum',
#  'westport',
#  'fresnillo',
#  'taoudenni',
#  'vao',
#  'baracoa',
#  'warqla',
#  'mahibadhoo',
#  'pryyutivka',
#  'malinyi',
#  'andra',
#  'amapa',
#  'korla',
#  'wanning',
#  'lagos',
#  'woodward',
#  'porteirinha',
#  'mlawa',
#  'vaitupu',
#  'paradwip',
#  'waw',
#  'sinkat',
#  'mercedes',
#  'hervey bay',
#  'ingham',
#  'pangody',
#  'dourados',
#  'sumbawa',
#  'calamar',
#  'codrington',
#  'taguatinga',
#  'garden city',
#  'fianga',
#  'north bend',
#  'puerto escondido',
#  'granada',
#  'kenai',
#  'mehran',
#  'nayudupeta',
#  'khargone',
#  'galbshtadt',
#  'okhotsk',
#  'port hedland',
#  'wolsztyn',
#  'paracatu',
#  'rijeka',
#  'balikpapan',
#  'baruun-urt',
#  'general pico',
#  'mosetse',
#  'isangel',
#  'kayes',
#  'awbari',
#  'pacific grove',
#  'columbus',
#  'camacupa',
#  'bria',
#  'longyearbyen',
#  'patnos',
#  'labuhan',
#  'bowen',
#  'bustamante',
#  'xichang',
#  'ambilobe',
#  'vesoul',
#  'isla mujeres',
#  'egvekinot',
#  'trelew',
#  'port antonio',
#  'meadow lake',
#  'dennis',
#  'were ilu',
#  'manavalakurichi',
#  'bac lieu',
#  'kloulklubed',
#  'mabaruma',
#  'shipunovo',
#  'ornskoldsvik',
#  'thinadhoo',
#  'arkhipo-osipovka',
#  'shaunavon',
#  'college',
#  'payo',
#  'yerbogachen',
#  'gladstone',
#  'dukat',
#  'moroni',
#  'alcaudete',
#  'paranagua',
#  'dryden',
#  'sorvag',
#  'alamosa',
#  'villarrica',
#  'tessalit',
#  'batemans bay',
#  'raudeberg',
#  'gondanglegi',
#  'orlik',
#  'faya',
#  'cap-aux-meules',
#  'gualeguaychu',
#  'ayolas',
#  'ola',
#  'moose factory',
#  'sakakah']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
totalCitiesSeries = []

for city in cities:
    try:
#city = input('pick a city ')
        baseUrl = "http://api.openweathermap.org/data/2.5/weather?q=" + city.replace(" ", "") + "&units=imperial&APPID="

        #baseUrl = "http://api.openweathermap.org/data/2.5/weather?lat=43.65&lon=-79.39&APPID="
        apiKey = "41ed0fa71109712597d1d5e12e282f0d"
        units = "units=metric"
        combinedUrl = baseUrl + apiKey 

        data = requests.get(combinedUrl).json()

        cityName = data['name']
        lon = data['coord']['lon']
        lat = data['coord']['lat']
        tempF = data['main']['temp']
        tempC = (data['main']['temp'] - 32) * .5556
        tempC = round(tempC, 2)
        humidityPercent = data['main']['humidity']
        cloudinessPercent = data['clouds']['all']
        windSpeedMph = data['wind']['speed']

        cityDataDict = {"Name": cityName, 
                "Longitude": lon, 
                "Latitude": lat, 
                "Temp(F)": tempF, 
                "Temp(C)": tempC, 
                "Humidity(%)": humidityPercent,
                "Cloudiness(%)": cloudinessPercent, 
                "Wind Speed(mph)": windSpeedMph}

        totalCitiesSeries.append(cityDataDict)
    except KeyError:
         continue
    
totalCitiesSeries
totalCitiesDF = pd.DataFrame(totalCitiesSeries)
print(totalCitiesDF)
# Out:
#      Cloudiness(%)  Humidity(%)  Latitude  Longitude              Name  \
# 0               64           84     38.13     140.30        Kaminoyama
# 1                0           33      8.96      38.73              Lebu
# 2               40           66    -42.88     147.33            Hobart
# 3               92           98    -46.19     168.86           Mataura
# 4               80           96    -23.12    -134.97           Rikitea
# 5               24           80     68.05      39.51         Ostrovnoy
# 6               92           94    -42.48     -73.76            Castro
# 7               92           86     67.55      63.78      Komsomolskiy
# 8               24           53     -4.09     -63.14             Coari
# 9                0           70     35.07     116.31          Jinxiang
# 10               0          100     77.48     -69.36           Qaanaaq
# 11              75           92     49.49    -117.29            Nelson
# 12              75           87    -54.81     -68.31           Ushuaia
# 13              92           95     65.61     -37.64          Tasiilaq
# 14              92           34    -33.21     138.60         Jamestown
# 15              20           49     45.67    -108.77            Laurel
# 16              75           83    -20.41      57.70         Mahebourg
# 17              64           91     55.27      31.52           Demidov
# 18              76           78      5.16     -52.64            Kourou
# 19               0           48     29.05    -109.23         Sahuaripa
# 20               0           55    -34.42      19.24          Hermanus
# 21               0          100     51.71     143.23          Katangli
# 22              90          100     47.66     -52.73            Torbay
# 23               0           95     15.34      74.49             Vaini
# 24              20           77    -26.80     153.14         Caloundra
# 25              75           36     60.91     -46.05            Narsaq
# 26               0           82    -22.28     166.46            Noumea
# 27               0           83    -34.00      24.73      Kruisfontein
# 28               8          100     -9.80    -139.03            Atuona
# 29               5           70     16.86     -99.88          Acapulco
# ..             ...          ...       ...        ...               ...
# 456              0           30    -43.25     -65.31            Trelew
# 457             90           87     36.02     -86.80        Meadowlake
# 458             90           71     41.74     -70.19            Dennis
# 459             75           88      8.13      77.30   Manavalakurichi
# 460             75           83      7.04     134.26       Kloulklubed
# 461             88           80      8.20     -59.78          Mabaruma
# 462             88           89     52.22      82.26         Shipunovo
# 463             90          100     63.29      18.72      Ornskoldsvik
# 464              8          100      0.53      72.93         Thinadhoo
# 465             92           97     44.37      38.53  Arkhipo-Osipovka
# 466             80           87     49.65    -108.41         Shaunavon
# 467             90           92     64.86    -147.80           College
# 468             92           99     -3.75     103.64              Payo
# 469             56           76     61.28     108.01       Yerbogachen
# 470             44           93    -23.84     151.26         Gladstone
# 471              0           79     42.44      22.31             Dukat
# 472              0           19     39.52    -111.59            Moroni
# 473             75           93     37.59      -4.08         Alcaudete
# 474             90           64     49.79     -92.84            Dryden
# 475              1           38     37.47    -105.87           Alamosa
# 476              0           61    -39.28     -72.23        Villarrica
# 477             88           26     20.20       1.01          Tessalit
# 478              8           93     61.99       5.14         Raudeberg
# 479             24           91     -7.75     112.01       Gondanglegi
# 480             44           46     52.51      99.83             Orlik
# 481              0           77     18.39      42.45              Faya
# 482             40           63     47.38     -61.86    Cap-aux-Meules
# 483              0           46    -33.01     -58.51      Gualeguaychu
# 484              0           86    -27.39     -56.84            Ayolas
# 485             75           92     59.58     151.30               Ola
#
#      Temp(C)  Temp(F)  Wind Speed(mph)
# 0       2.44    36.39             3.09
# 1      10.16    50.29             6.26
# 2      13.00    55.40            10.29
# 3       5.19    41.34            19.35
# 4      24.71    76.48            14.16
# 5      -2.61    27.30            15.17
# 6      12.89    55.20            11.14
# 7      -8.71    16.32            24.79
# 8      33.19    91.74             4.43
# 9       0.16    32.29             6.78
# 10    -23.07    -9.52             9.46
# 11     -2.00    28.40             2.08
# 12      8.19    46.74            32.21
# 13      2.00    35.60            55.25
# 14     25.66    78.19            12.19
# 15      3.90    39.02            13.87
# 16     24.00    75.20             5.82
# 17     -0.49    31.12             9.28
# 18     28.00    82.40            12.75
# 19     20.44    68.79             1.63
# 20     20.16    68.29             2.57
# 21     -5.34    22.39             8.46
# 22      0.62    33.12             9.17
# 23     20.71    69.28             2.75
# 24     17.00    62.60             5.82
# 25      7.00    44.60            19.46
# 26     17.00    62.60             2.24
# 27     20.04    68.07            11.59
# 28     26.76    80.17            16.40
# 29     30.00    86.00             4.70
# ..       ...      ...              ...
# 456    26.96    80.53            21.43
# 457    13.66    56.59            12.75
# 458    11.31    52.36             9.17
# 459    26.00    78.80             3.36
# 460    27.00    80.60             5.82
# 461    28.89    84.00             7.78
# 462    -7.39    18.70             9.06
# 463    -3.89    25.00             6.93
# 464    27.94    82.29             5.03
# 465     7.94    46.29             5.55
# 466     1.79    35.22             5.26
# 467    -7.69    18.16             3.53
# 468    22.46    72.43             4.32
# 469   -24.62   -12.31             2.75
# 470    19.69    67.44             7.38
# 471    -2.29    27.88             2.08
# 472     2.61    36.70             1.86
# 473    10.00    50.00            13.87
# 474   -17.00     1.40             6.93
# 475     2.20    35.96             2.86
# 476    17.96    64.33             3.13
# 477    25.31    77.56             3.87
# 478     4.00    39.20             6.93
# 479    19.11    66.40             2.35
# 480   -24.49   -12.08             3.87
# 481    16.51    61.72             3.58
# 482    -1.00    30.20            18.34
# 483    26.96    80.53             9.17
# 484    23.91    75.04            10.13
# 485   -13.00     8.60             2.24
#
# [486 rows x 8 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
cityLatX = totalCitiesDF['Latitude']
cityTempFY = totalCitiesDF['Temp(F)']
cityTempCY = totalCitiesDF['Temp(C)']

latVStempF = plt.scatter(cityLatX, cityTempFY, color="yellow", label="Fahrenheit", alpha=".7", edgecolors= "black", s=100)
latVStempC = plt.scatter(cityLatX, cityTempCY, color="lightblue", label="Celcius", alpha=".7", edgecolors= "black", s=100)

plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Latitude vs. Temperature Plot')
legend = plt.legend(title="Temperature", loc='upper right')
legend.legendHandles[0]._sizes = [100]
legend.legendHandles[1]._sizes = [100]
plt.grid(True)
plt.savefig("latitudevstemperatureplot.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e30a7b3ec14f> in <module>()
# ----> 1 cityLatX = totalCitiesDF['Latitude']
#       2 cityTempFY = totalCitiesDF['Temp(F)']
#       3 cityTempCY = totalCitiesDF['Temp(C)']
#       4
#       5 latVStempF = plt.scatter(cityLatX, cityTempFY, color="yellow", label="Fahrenheit", alpha=".7", edgecolors= "black", s=100)
#
# NameError: name 'totalCitiesDF' is not defined

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
cityLatX = totalCitiesDF['Latitude']
cityHumidityY = totalCitiesDF['Humidity(%)']


latVShumidity = plt.scatter(cityLatX, cityHumidityY, color="purple", label="Humidity", alpha=".7", edgecolors= "black", s=100)

plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Latitude vs. Humidity Plot')
plt.grid(True)
plt.savefig("latitudevshumidityplot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cityLatX = totalCitiesDF['Latitude']
cityCloudinessY = totalCitiesDF['Cloudiness(%)']


latVScloudiness = plt.scatter(cityLatX, cityCloudinessY, color="grey", label="Cloudiness", alpha=".7", edgecolors= "black", s=100)

plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('Latitude vs. Cloudiness Plot')
plt.grid(True)
plt.savefig("latitudevscloudinessplot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
cityLatX = totalCitiesDF['Latitude']
cityWindSpeedY = totalCitiesDF['Wind Speed(mph)']


latVSwind = plt.scatter(cityLatX, cityWindSpeedY, color="green", label="Wind Speed (mph)", alpha=".7", edgecolors= "black", s=100)

plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.title('Latitude vs. Wind Speed Plot')
plt.grid(True)
plt.savefig("latitudevswindspeedplot.png")
plt.show()
